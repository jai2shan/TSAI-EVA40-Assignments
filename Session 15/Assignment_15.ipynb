# %% [markdown]
# <a href="https://colab.research.google.com/github/jai2shan/TSAI-EVA40-Assignments/blob/master/Session%2015/Assignment_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.chdir(r'/content/drive/My Drive/Assignment  15 - 16k Images')

# %%
# !unzip 'overlaid masks.zip' -d '/content/Assignment 15'
# !unzip 'Overlaid.zip' -d '/content/Assignment 15'
# !unzip 'Depths.zip' -d '/content/Assignment 15'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Assignment 15/Depths/bg007_fg151_02.png
#   inflating: /content/Assignment 15/Depths/bg007_fg151_03.png
#   inflating: /content/Assignment 15/Depths/bg007_fg151_04.png
#   inflating: /content/Assignment 15/Depths/bg007_fg151_05.png
#   inflating: /content/Assignment 15/Depths/bg007_fg151_06.png
#   inflating: /content/Assignment 15/Depths/bg007_fg151_07.png
#   inflating: /content/Assignment 15/Depths/bg007_fg151_08.png
#   inflating: /content/Assignment 15/Depths/bg007_fg151_09.png
#   inflating: /content/Assignment 15/Depths/bg007_fg151_10.png
#   inflating: /content/Assignment 15/Depths/bg007_fg151_11.png
#   inflating: /content/Assignment 15/Depths/bg007_fg151_12.png
#   inflating: /content/Assignment 15/Depths/bg007_fg151_13.png
#   inflating: /content/Assignment 15/Depths/bg007_fg151_14.png
#   inflating: /content/Assignment 15/Depths/bg007_fg151_15.png
# ...

# %%
zip_ref = zipfile.ZipFile("/content/drive/My Drive/ML/DataSet.zip", 'r')
zip_ref.extractall("/content/Assignment 15")
zip_ref.close()

# %%
os.listdir('/content/Assignment 15')
# Out:
# ['overlaid masks']
